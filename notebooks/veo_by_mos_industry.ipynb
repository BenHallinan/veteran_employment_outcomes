# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.plotting import autocorrelation_plot

# %%
raw_veo_mos_industry_df = pd.read_excel('../data/veopu.xlsx', sheet_name="By DOD Occupation-Industry")

# %%
temp_df = raw_veo_mos_industry_df.drop([0,1], axis=0).drop(
    ['Unnamed: 4', 'Veterans Employment Outcomes By DOD Occupation-Industry','Unnamed: 1', 'Unnamed: 3'],axis=1
    )
temp_df.columns = temp_df.iloc[0]
temp_df = temp_df[1:]
veo_mos_industry_df = temp_df.reset_index(drop=True)
veo_mos_industry_df
# Out:
# 2   label_cohort dod_occ_code           label_dod_occ_code ind_level industry  \
# 0      2000-2015            0              All occupations         A       00
# 1      2000-2015            0              All occupations         N       11
# 2      2000-2015            0              All occupations         N       21
# 3      2000-2015            0              All occupations         N       22
# 4      2000-2015            0              All occupations         N       23
# ..           ...          ...                          ...       ...      ...
# 655    2008-2015          18X  Service and Supply Handlers         N       71
# 656    2008-2015          18X  Service and Supply Handlers         N       72
# 657    2008-2015          18X  Service and Supply Handlers         N       81
# 658    2008-2015          18X  Service and Supply Handlers         N       92
# 659    2008-2015          18X  Service and Supply Handlers         N       99
#
# ...
